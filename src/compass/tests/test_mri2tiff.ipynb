# %%
# %load_ext autoreload
# %autoreload 2

# %%
from core import MRI, mri2tiff
from pathlib import Path

# %%
img_path = Path("../../../data/pyramid_0.h5")
img = MRI(img_path)

# %%
print(img.info)
# Out:
# {'channel_names': array(['R', 'G', 'B'], dtype=object), 'dimension_names': array(['y', 'x', 'c'], dtype=object), 'extent': array([[39360, 19680,  9840,  4920,  2460,  1230,   615,   307,   153],
#        [43776, 21888, 10944,  5472,  2736,  1368,   684,   342,   171]]), 'mag_step': np.int64(2), 'max_level': np.int64(9), 'mpp_x': np.float64(0.22990091270662344), 'mpp_y': np.float64(0.2299061982711054), 'objective_power': np.float64(40.0)}

# %%
dst_path = img_path.with_suffix('.tiff')

mt = mri2tiff(img, dst_path, minimal_omexml=True)
print(mt)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#     <OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06"
#         xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
#         xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">
#         <Instrument ID="Instrument:0">
#             <Microscope Manufacturer="virtual" Model="v1"/>
#             <Objective Manufacturer="virtual" Model="v1" ID="Objective:0" NominalMagnification="40.0"/>
#         </Instrument>
#         <Image ID="Image:0" Name="pyramid_0">
#             <InstrumentRef ID="Instrument:0"/>
#             <!-- Minimum required fields about image dimensions -->
#             <Pixels DimensionOrder="XYCZT"
#                     ID="Pixels:0"
#                     SizeC="3"
#                     SizeT="1"
#                     SizeX="39360"
#                     SizeY="43776"
#                     SizeZ="1"
#                     Type="uint8"
# ...
