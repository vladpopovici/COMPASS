# %%
# %load_ext autoreload
# %autoreload 2

# %%
from core import WSI, wsi2netcdf
from pathlib import Path

# %%
wsi_path = "/home/vlad/Projects/tmp/wsi/SB001-T01-01-HE.mrxs"
dst_path = "/home/vlad/Projects/tmp/wsi/SB001-T01-01-HE.nc"

# %%
wsi2netcdf(wsi_path, dst_path)
