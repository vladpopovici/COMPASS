# %%
from compass.core import MRI, wsi2hdf5
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
src_file = "/home/vlad/Projects/SpTx/visium/SN124-v2/SN124_A551763_Rep2.h5"
lvl = 6

# %%
mri = MRI(src_file)

# %%
mri._info
# Out:
# {'base_mag_step': np.int64(2),
#  'base_mpp': np.float64(0.22990355548886443),
#  'base_objective_power': np.float64(40.0),
#  'compass_version': np.float64(1.0),
#  'level_count': np.int64(8),
#  'numpy_ordering': np.int64(1)}

# %%
img = mri.get_plane(lvl, as_type=np.uint8)

# %%
plt.imshow(img)

# %%
src_file = "/home/vlad/Projects/SpTx/visium/SN124-v2/SN124_A798015_Rep2.h5"
lvl = 6

# %%
mri = MRI(src_file)
img = mri.get_plane(lvl, as_type=np.uint8)
plt.imshow(img)

# %%
slide_file = "/home/vlad/Projects/SpTx/visium/SN124.ndpi"

# %%
# 1st patch
x0, y0 = 0, 0
w, h = 39360, 39168

wsi2hdf5(
    slide_file, 
    "patch1.h5",
    crop=(x0, y0, w, h)
)
# Out:
# 2026-01-15 12:35:48,052 - INFO - WSI2HDF5: 8 levels to generate (level 0 is just a copy)
# 2026-01-15 12:35:48,053 - INFO - WSI2HDF5: Copy base level...
# 2026-01-15 12:35:48,073 - INFO - WSI2HDF5: ...crop 0, 0, 39360, 39168
# 2026-01-15 12:35:48,076 - INFO - VIPS: vips__open_image_write: simple open
# ========= WSI2HDF5 ===========
# Source: /home/vlad/Projects/SpTx/visium/SN124.ndpi
# Destination: patch1.h5
# Crop: (0, 0) x (39360, 39168)
# 2026-01-15 12:35:54,178 - INFO - VIPS: threadpool completed with 13 workers
# 2026-01-15 12:35:54,199 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:54,200 - INFO - WSI2HDF5: Generating level 1...
# 2026-01-15 12:35:54,201 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:54,202 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:54,202 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:54,202 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:54,203 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,137 - INFO - VIPS: threadpool completed with 14 workers
# 2026-01-15 12:35:56,140 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,141 - INFO - WSI2HDF5: Generating level 2...
# 2026-01-15 12:35:56,142 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:56,142 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:56,143 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:56,143 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:56,144 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,474 - INFO - VIPS: threadpool completed with 4 workers
# 2026-01-15 12:35:56,475 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,476 - INFO - WSI2HDF5: Generating level 3...
# 2026-01-15 12:35:56,477 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:56,477 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:56,477 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:56,479 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:56,481 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,559 - INFO - VIPS: threadpool completed with 12 workers
# 2026-01-15 12:35:56,561 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,561 - INFO - WSI2HDF5: Generating level 4...
# 2026-01-15 12:35:56,562 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:56,563 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:56,563 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:56,564 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:56,564 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,586 - INFO - VIPS: threadpool completed with 1 workers
# 2026-01-15 12:35:56,588 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,588 - INFO - WSI2HDF5: Generating level 5...
# 2026-01-15 12:35:56,590 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:56,590 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:56,590 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:56,591 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:56,591 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,599 - INFO - VIPS: threadpool completed with 3 workers
# 2026-01-15 12:35:56,603 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,603 - INFO - WSI2HDF5: Generating level 6...
# 2026-01-15 12:35:56,605 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:56,606 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:56,606 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:56,606 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:56,607 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,610 - INFO - VIPS: threadpool completed with 1 workers
# 2026-01-15 12:35:56,616 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,616 - INFO - WSI2HDF5: Generating level 7...
# 2026-01-15 12:35:56,619 - INFO - VIPS: reducev: 13 point mask
# 2026-01-15 12:35:56,619 - INFO - VIPS: reducev: using vector path
# 2026-01-15 12:35:56,620 - INFO - VIPS: reduceh: 13 point mask
# 2026-01-15 12:35:56,620 - INFO - VIPS: reduceh: using vector path
# 2026-01-15 12:35:56,621 - INFO - VIPS: vips__open_image_write: simple open
# 2026-01-15 12:35:56,622 - INFO - VIPS: threadpool completed with 3 workers
# 2026-01-15 12:35:56,638 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:35:56,639 - INFO - WSI2HDF5: From temporary to destination
# 2026-01-15 12:35:56,640 - INFO - WSI2HDF5: Copying level 0...
# 2026-01-15 12:35:56,678 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:35:57,718 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:35:57,946 - INFO - VIPS: threadpool completed with 14 workers
# 2026-01-15 12:35:58,094 - INFO - VIPS: threadpool completed with 15 workers
# 2026-01-15 12:35:58,290 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:35:58,441 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:35:59,473 - INFO - VIPS: threadpool completed with 4 workers
# 2026-01-15 12:35:59,661 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:35:59,893 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:00,132 - INFO - VIPS: threadpool completed with 7 workers
# 2026-01-15 12:36:00,372 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:01,632 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:01,960 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:02,253 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:02,521 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:02,808 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:03,115 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:03,833 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:04,065 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:04,299 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:04,536 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:04,773 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:05,521 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:05,761 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:05,999 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:06,188 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:06,252 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:06,253 - INFO - WSI2HDF5: Copying level 1...
# 2026-01-15 12:36:06,327 - INFO - VIPS: threadpool completed with 6 workers
# 2026-01-15 12:36:06,717 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:06,840 - INFO - VIPS: threadpool completed with 13 workers
# 2026-01-15 12:36:06,961 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:07,085 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:07,205 - INFO - VIPS: threadpool completed with 13 workers
# 2026-01-15 12:36:07,620 - INFO - VIPS: threadpool completed with 6 workers
# 2026-01-15 12:36:07,742 - INFO - VIPS: threadpool completed with 5 workers
# 2026-01-15 12:36:07,877 - INFO - VIPS: threadpool completed with 5 workers
# 2026-01-15 12:36:08,000 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:08,121 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:08,547 - INFO - VIPS: threadpool completed with 12 workers
# 2026-01-15 12:36:08,650 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:08,698 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:08,698 - INFO - WSI2HDF5: Copying level 2...
# 2026-01-15 12:36:08,732 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:08,971 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,027 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,069 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,112 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,157 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,468 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,484 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:09,485 - INFO - WSI2HDF5: Copying level 3...
# 2026-01-15 12:36:09,513 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,592 - INFO - VIPS: threadpool completed with 14 workers
# 2026-01-15 12:36:09,618 - INFO - VIPS: threadpool completed with 16 workers
# 2026-01-15 12:36:09,626 - INFO - VIPS: threadpool completed with 2 workers
# 2026-01-15 12:36:09,629 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:09,629 - INFO - WSI2HDF5: Copying level 4...
# 2026-01-15 12:36:09,638 - INFO - VIPS: threadpool completed with 5 workers
# 2026-01-15 12:36:09,649 - INFO - VIPS: threadpool completed with 8 workers
# 2026-01-15 12:36:09,652 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:09,652 - INFO - WSI2HDF5: Copying level 5...
# 2026-01-15 12:36:09,659 - INFO - VIPS: threadpool completed with 6 workers
# 2026-01-15 12:36:09,662 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:09,662 - INFO - WSI2HDF5: Copying level 6...
# 2026-01-15 12:36:09,666 - INFO - VIPS: threadpool completed with 3 workers
# 2026-01-15 12:36:09,667 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:09,668 - INFO - WSI2HDF5: Copying level 7...
# 2026-01-15 12:36:09,677 - INFO - VIPS: threadpool completed with 10 workers
# 2026-01-15 12:36:09,679 - INFO - WSI2HDF5: ...OK
# 2026-01-15 12:36:09,680 - INFO - WSI2HDF5: remove temporary files.

# %%
# 2nd patch
x0, y0 = 39360, 0
w, h = 39360, 39168

wsi2hdf5(
    slide_file, 
    "patch2.h5",
    crop=(x0, y0, w, h)
)
